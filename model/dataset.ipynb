# %% [markdown]
# The Million Song Dataset is quite old and the data is very segragated, uses a lot of different formats (txt, hdf5, sqlite3 etc.). This notebook lays down the steps to aggregate these files together and setup the required data for final model.
#
# Note: You can skip running this notebook to directly work with the model.ipynb for demo since we provide the aggregated data already as part of files (song_genre_year.csv).
#
# Also, if you wish to run with the whole dataset we recommend running this on Google colab/PACE cluster, your kernel might crash due to insufficient memory.
#
# This notebook has been optimized to run with 12.7 GB RAM on Google Colab when working with full 1 Million songs, freeing up memory at each step. Requesting for similar resources to Google Colab on https://ondemand-ice.pace.gatech.edu/pun/sys/dashboard/ should also be sufficient.
#
# We provide you the option to customize number of rows. Have set it a low number for demo purposes on personal system. Feel free to try out on a bigger subset or whole dataset as per your resources.

# %% [markdown]
# Before you run the notebook, create a virtual environment using the following cmd in this directory
# python3 -m venv venv
#
# Then select venv using
# source venv/bin/activate
#
# Or alternatively make sure you install packages from requirements.txt

# %%
# !pip3 install -r requirements.txt
# Out:
# Requirement already satisfied: asttokens==2.4.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: comm==0.2.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: debugpy==1.8.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: decorator==5.1.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: exceptiongroup==1.2.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: executing==2.0.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: Faker==20.1.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (20.1.0)
# Requirement already satisfied: h5py==3.10.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (3.10.0)
# Requirement already satisfied: ipykernel==6.27.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (6.27.1)
# Requirement already satisfied: ipython==8.18.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (8.18.1)
# Requirement already satisfied: jedi==0.19.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (0.19.1)
# Requirement already satisfied: joblib==1.3.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (1.3.2)
# Requirement already satisfied: jupyter_client==8.6.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (8.6.0)
# Requirement already satisfied: jupyter_core==5.5.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (5.5.0)
# Requirement already satisfied: matplotlib-inline==0.1.6 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (0.1.6)
# Requirement already satisfied: nest-asyncio==1.5.8 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (1.5.8)
# Requirement already satisfied: numpy==1.26.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (1.26.2)
# Requirement already satisfied: packaging==23.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (23.2)
# Requirement already satisfied: pandas==2.1.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (2.1.3)
# Requirement already satisfied: parso==0.8.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (0.8.3)
# Requirement already satisfied: pexpect==4.9.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 21)) (4.9.0)
# Requirement already satisfied: platformdirs==4.0.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (4.0.0)
# Requirement already satisfied: prompt-toolkit==3.0.41 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 23)) (3.0.41)
# Requirement already satisfied: psutil==5.9.6 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (5.9.6)
# Requirement already satisfied: ptyprocess==0.7.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 26)) (0.2.2)
# Requirement already satisfied: Pygments==2.17.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (2.17.2)
# Requirement already satisfied: python-dateutil==2.8.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (2.8.2)
# Requirement already satisfied: pytz==2023.3.post1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 29)) (2023.3.post1)
# Requirement already satisfied: pyzmq==25.1.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 30)) (25.1.1)
# Requirement already satisfied: scikit-learn==1.3.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 31)) (1.3.2)
# Requirement already satisfied: scipy==1.11.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 32)) (1.11.4)
# Requirement already satisfied: six==1.16.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 33)) (1.16.0)
# Requirement already satisfied: stack-data==0.6.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 34)) (0.6.3)
# Requirement already satisfied: threadpoolctl==3.2.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 35)) (3.2.0)
# Requirement already satisfied: tornado==6.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 36)) (6.4)
# Requirement already satisfied: tqdm==4.66.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 37)) (4.66.1)
# Requirement already satisfied: traitlets==5.14.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 38)) (5.14.0)
# Requirement already satisfied: tzdata==2023.3 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 39)) (2023.3)
# Requirement already satisfied: wcwidth==0.2.12 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 40)) (0.2.12)

# %% [markdown]
# We will be downloading the files required to run this notebook: (either run following cell or download manually) <br>
# Song Meta Data Summary HDF5 file: http://millionsongdataset.com/sites/default/files/AdditionalFiles/msd_summary_file.h5 <br>
# Genre Dataset: https://www.tagtraum.com/genres/msd_tagtraum_cd2c.cls.zip <br>
# Year Dataset: http://millionsongdataset.com/sites/default/files/AdditionalFiles/tracks_per_year.txt

# %%
# !wget http://millionsongdataset.com/sites/default/files/AdditionalFiles/msd_summary_file.h5
# !wget http://millionsongdataset.com/sites/default/files/AdditionalFiles/tracks_per_year.txt
# !wget https://www.tagtraum.com/genres/msd_tagtraum_cd2c.cls.zip
# !wget http://millionsongdataset.com/sites/default/files/challenge/train_triplets.txt.zip
# Out:
# --2023-12-02 16:07:12--  http://millionsongdataset.com/sites/default/files/AdditionalFiles/msd_summary_file.h5
# Resolving millionsongdataset.com (millionsongdataset.com)...
# 172.104.14.177
# Connecting to millionsongdataset.com (millionsongdataset.com)|172.104.14.177|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 316104481 (301M)
# Saving to: ‘msd_summary_file.h5.2’
#
# msd_summary_file.h5  81%[===============>    ] 246.98M  2.82MB/s    eta 37s    ^C
# --2023-12-02 16:09:59--  http://millionsongdataset.com/sites/default/files/AdditionalFiles/tracks_per_year.txt
# Resolving millionsongdataset.com (millionsongdataset.com)... 172.104.14.177
# Connecting to millionsongdataset.com (millionsongdataset.com)|172.104.14.177|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35028078 (33M) [text/plain]
# Saving to: ‘tracks_per_year.txt.2’
#
# tracks_per_year.txt  44%[=======>            ]  14.74M   694KB/s    eta 17s    ^C
# --2023-12-02 16:10:24--  https://www.tagtraum.com/genres/msd_tagtraum_cd2c.cls.zip
# Resolving www.tagtraum.com (www.tagtraum.com)... 81.169.145.77, 2a01:238:20a:202:1077::
# Connecting to www.tagtraum.com (www.tagtraum.com)|81.169.145.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1621202 (1.5M) [application/zip]
# Saving to: ‘msd_tagtraum_cd2c.cls.zip.2’
#
# msd_tagtraum_cd2c.c 100%[===================>]   1.55M   742KB/s    in 2.1s
#
# 2023-12-02 16:10:28 (742 KB/s) - ‘msd_tagtraum_cd2c.cls.zip.2’ saved [1621202/1621202]
#
# --2023-12-02 16:10:28--  http://millionsongdataset.com/sites/default/files/challenge/train_triplets.txt.zip
# Resolving millionsongdataset.com (millionsongdataset.com)...

# %% [markdown]
# In the following row set the number of songs you want to work with. We have initialized to to 10_000. It can go upto 1_000_000. If you want to work with the whole 1 Million Song Dataset, we recommend using Google Colab/PACE cluster. We worked with it on Google Colab.

# %%
nrows = 10_000

# %%
import h5py
import pandas as pd

h5_file_path = "msd_summary_file.h5"
with h5py.File(h5_file_path, "r") as h5file:
    songs_dataset = h5file["metadata"]["songs"][:nrows]
    analysis_dataset = h5file["analysis"]["songs"][:nrows]
    musicbrainz_dataset = h5file["musicbrainz"]["songs"][:nrows]

    songs_data = songs_dataset[()]
    analysis_data = analysis_dataset[()]
    musicbrainz_data = musicbrainz_dataset[()]

songs_df = pd.DataFrame(songs_data)
analysis_df = pd.DataFrame(analysis_data)
musicbrainz_df = pd.DataFrame(musicbrainz_data)

print(songs_df.columns)
print(analysis_df.columns)
print(musicbrainz_df.columns)
# Out:
# Index(['analyzer_version', 'artist_7digitalid', 'artist_familiarity',
#        'artist_hotttnesss', 'artist_id', 'artist_latitude', 'artist_location',
#        'artist_longitude', 'artist_mbid', 'artist_name', 'artist_playmeid',
#        'genre', 'idx_artist_terms', 'idx_similar_artists', 'release',
#        'release_7digitalid', 'song_hotttnesss', 'song_id', 'title',
#        'track_7digitalid'],
#       dtype='object')
# Index(['analysis_sample_rate', 'audio_md5', 'danceability', 'duration',
#        'end_of_fade_in', 'energy', 'idx_bars_confidence', 'idx_bars_start',
#        'idx_beats_confidence', 'idx_beats_start', 'idx_sections_confidence',
#        'idx_sections_start', 'idx_segments_confidence',
#        'idx_segments_loudness_max', 'idx_segments_loudness_max_time',
#        'idx_segments_loudness_start', 'idx_segments_pitches',
#        'idx_segments_start', 'idx_segments_timbre', 'idx_tatums_confidence',
#        'idx_tatums_start', 'key', 'key_confidence', 'loudness', 'mode',
#        'mode_confidence', 'start_of_fade_out', 'tempo', 'time_signature',
#        'time_signature_confidence', 'track_id'],
#       dtype='object')
# Index(['idx_artist_mbtags', 'year'], dtype='object')

# %%
msd_df = pd.concat([songs_df, analysis_df, musicbrainz_df], axis=1)
del songs_df
del analysis_df
del musicbrainz_df

# %%
msd_df = msd_df.applymap(
    lambda x: x.decode("utf-8") if isinstance(x, bytes) else x
)
msd_df.drop(["year", "genre"], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_80770/669961607.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   msd_df = msd_df.applymap(

# %%
# !unzip "msd_tagtraum_cd2c.cls.zip"
# Out:
# Archive:  msd_tagtraum_cd2c.cls.zip
# replace msd_tagtraum_cd2c.cls? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
file_path = "msd_tagtraum_cd2c.cls"

genre_df = pd.read_csv(
    file_path,
    sep="\t",
    header=None,
    names=["track_id", "genre", "minority_genre"],
    comment="#",
)

genre_df
# Out:
#                   track_id       genre  minority_genre
# 0       TRAAAAK128F9318786        Rock             NaN
# 1       TRAAAAW128F429D538         Rap             NaN
# 2       TRAAADJ128F4287B47        Rock             NaN
# 3       TRAAADZ128F9348C2E       Latin             NaN
# 4       TRAAAED128E0783FAB        Jazz             NaN
# ...                    ...         ...             ...
# 191396  TRZZZMY128F426D7A2      Reggae             NaN
# 191397  TRZZZRJ128F42819AF        Rock             NaN
# 191398  TRZZZUK128F92E3C60        Folk             NaN
# 191399  TRZZZZD128F4236844        Rock             NaN
# 191400  TRZZZZZ12903D05E3A  Electronic             NaN
#
# [191401 rows x 3 columns]

# %%
genre_df.drop(["minority_genre"], axis=1, inplace=True)
genre_df.head
# Out:
# <bound method NDFrame.head of                   track_id       genre
# 0       TRAAAAK128F9318786        Rock
# 1       TRAAAAW128F429D538         Rap
# 2       TRAAADJ128F4287B47        Rock
# 3       TRAAADZ128F9348C2E       Latin
# 4       TRAAAED128E0783FAB        Jazz
# ...                    ...         ...
# 191396  TRZZZMY128F426D7A2      Reggae
# 191397  TRZZZRJ128F42819AF        Rock
# 191398  TRZZZUK128F92E3C60        Folk
# 191399  TRZZZZD128F4236844        Rock
# 191400  TRZZZZZ12903D05E3A  Electronic
#
# [191401 rows x 2 columns]>

# %%
msd_df = genre_df.merge(msd_df, on="track_id")
del genre_df

# %%
file_path = (
    "tracks_per_year.txt"
)

year_df = pd.read_csv(
    file_path,
    sep="<SEP>",
    header=None,
    names=["year", "track_id", "song_name", "artist_name"],
)

year_df.head
# Out:
# /tmp/ipykernel_80770/3607606576.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   year_df = pd.read_csv(
# <bound method NDFrame.head of         year            track_id           song_name  \
# 0       1922  TRSGHLU128F421DF83      Alberta Hunter
# 1       1922  TRMYDFV128F42511FC     Barrington Levy
# 2       1922  TRRAHXQ128F42511FF     Barrington Levy
# 3       1922  TRFAFTK12903CC77B8     Barrington Levy
# 4       1922  TRSTBUY128F4251203     Barrington Levy
# ...      ...                 ...                 ...
# 515571  2010  TRPLSGR128F930135B      Ólafur Arnalds
# 515572  2010  TRLYTZU128F930135F      Ólafur Arnalds
# 515573  2010  TRJHYON128F9301354      Ólafur Arnalds
# 515574  2010  TRXQZXQ128F9301352      Ólafur Arnalds
# 515575  2011  TRCGTAH12903CAFAB8  The Joy Formidable
#
#                           artist_name
# 0                        Don't Pan Me
# 1                  Warm And Sunny Day
# 2                     Looking My Love
# 3                  Warm And Sunny Day
# 4                 Mandela You're Free
# ...                               ...
# 515571  Loftið verður skyndilega kalt
# 515572                   Gleypa okkur
# 515573                  Þú ert jörðin
# 515574                   Þú ert sólin
# 515575                       Popinjay
#
# [515576 rows x 4 columns]>

# %%
year_df.drop(["song_name", "artist_name"], axis=1, inplace=True)

# %%
msd_df = msd_df.merge(year_df, on="track_id")
del year_df
msd_df.head
# Out:
# <bound method NDFrame.head of                 track_id       genre analyzer_version  artist_7digitalid  \
# 0     TRMBAEP128F92FF86F  Electronic                               51120
# 1     TRMBAGK128F92E59B5        Jazz                                9580
# 2     TRMBALI128F4263C1B        Jazz                                 777
# 3     TRMBANE128F423ECDB        Rock                               87687
# 4     TRMBAXZ12903CF4300       Metal                               90917
# ...                  ...         ...              ...                ...
# 1469  TRMWZNP128F931E7B8  Electronic                               70840
# 1470  TRMWZUQ128F934B40C       Metal                              111353
# 1471  TRMWZWM128F92E8341     Country                               26388
# 1472  TRMWZXH128F930691C        Rock                              106258
# 1473  TRMWZZR128F42AE75E        Rock                               52287
#
#       artist_familiarity  artist_hotttnesss           artist_id  \
# 0               0.648431           0.502925  ARM8OOX1187B989F89
# 1               0.676090           0.492258  AR1QF001187B9B2B9F
# 2               0.569424           0.412925  ARMMI1S1187B9902BF
# 3               0.782527           0.601843  ARG00DS1187B9ADFC8
# 4               0.661376           0.512047  AR9AR5R1187B99BDA9
# ...                  ...                ...                 ...
# 1469            0.496979           0.434256  AR226CG1187B9B1748
# 1470            0.592299           0.433459  ARVTQ251187FB3EEE1
# 1471            0.689378           0.400419  ARAPRJI1187B9ACEBD
# 1472            0.522272           0.366043  ARXV8B11187FB382F9
# 1473            0.705876           0.620948  ARNZ70R1187B9A4824
#
#       artist_latitude            artist_location  artist_longitude  ...  \
# 0            51.50632            London, England          -0.12714  ...
# 1                 NaN                Concord, CA               NaN  ...
# 2            39.74001                 Denver, CO        -104.99226  ...
# 3            27.97580                    Florida         -81.54106  ...
# 4            45.51228   Montreal, Quebec, Canada         -73.55439  ...
# ...               ...                        ...               ...  ...
# 1469              NaN                                          NaN  ...
# 1470              NaN                                          NaN  ...
# 1471         36.16778              Nashville, TN         -86.77836  ...
# 1472              NaN                                          NaN  ...
# 1473              NaN  Westbury, Long Island, NY               NaN  ...
#
#      key_confidence loudness  mode  mode_confidence  start_of_fade_out  \
# 0             0.662   -7.308     1            0.566            383.570
# 1             0.481  -16.728     1            0.505            475.089
# 2             0.000  -15.708     0            0.073            310.050
# 3             0.365   -4.672     1            0.518            243.467
# 4             0.000   -5.555     1            0.233            163.457
# ...             ...      ...   ...              ...                ...
# 1469          0.982  -20.835     1            0.902            605.501
# 1470          0.066   -7.761     1            0.372            104.228
# 1471          0.866   -9.553     1            0.830            292.310
# 1472          0.717  -14.722     0            0.571            218.389
# 1473          0.516   -4.903     1            0.540            276.108
#
#         tempo  time_signature  time_signature_confidence idx_artist_mbtags  \
# 0     147.979               4                      0.306                 0
# 1     109.892               4                      0.670                 0
# 2     107.975               3                      1.000                 0
# 3      85.296               5                      0.797                 0
# 4     145.574               3                      0.728                 0
# ...       ...             ...                        ...               ...
# 1469   79.425               5                      0.711                 0
# 1470   92.705               3                      0.200                 0
# 1471  110.100               4                      0.595                 0
# 1472  164.004               4                      0.536                 0
# 1473  132.798               4                      0.426                 0
#
#       year
# 0     2003
# 1     1988
# 2     1989
# 3     2005
# 4     2007
# ...    ...
# 1469  2006
# 1470  2004
# 1471  2000
# 1472  1969
# 1473  2006
#
# [1474 rows x 53 columns]>

# %%
msd_df.columns.to_list()
# Out:
# ['track_id',
#  'genre',
#  'analyzer_version',
#  'artist_7digitalid',
#  'artist_familiarity',
#  'artist_hotttnesss',
#  'artist_id',
#  'artist_latitude',
#  'artist_location',
#  'artist_longitude',
#  'artist_mbid',
#  'artist_name',
#  'artist_playmeid',
#  'idx_artist_terms',
#  'idx_similar_artists',
#  'release',
#  'release_7digitalid',
#  'song_hotttnesss',
#  'song_id',
#  'title',
#  'track_7digitalid',
#  'analysis_sample_rate',
#  'audio_md5',
#  'danceability',
#  'duration',
#  'end_of_fade_in',
#  'energy',
#  'idx_bars_confidence',
#  'idx_bars_start',
#  'idx_beats_confidence',
#  'idx_beats_start',
#  'idx_sections_confidence',
#  'idx_sections_start',
#  'idx_segments_confidence',
#  'idx_segments_loudness_max',
#  'idx_segments_loudness_max_time',
#  'idx_segments_loudness_start',
#  'idx_segments_pitches',
#  'idx_segments_start',
#  'idx_segments_timbre',
#  'idx_tatums_confidence',
#  'idx_tatums_start',
#  'key',
#  'key_confidence',
#  'loudness',
#  'mode',
#  'mode_confidence',
#  'start_of_fade_out',
#  'tempo',
#  'time_signature',
#  'time_signature_confidence',
#  'idx_artist_mbtags',
#  'year']

# %% [markdown]
# msd_df was saved to a file as song_genre_year.csv which we work with in our model.

# %% [markdown]
# Following code snippets are to generate files and add support for the UI to consume in an easy manner. Not an important part, but you can wish to go through it.

# %% [markdown]
# Year Genre Song Hottness Count Chart

# %%
chart_df = msd_df[["song_id", "genre", "year", "song_hotttnesss", "duration"]]
chart_df = (
    chart_df.groupby(["year", "genre"])
    .agg({"song_hotttnesss": "mean", "duration": "mean", "song_id": "size"})
    .reset_index()
)
chart_df = chart_df.rename(columns={"song_id": "count"})
chart_df["song_hotttnesss"].fillna(0, inplace=True)

unique_years = chart_df["year"].unique()
unique_genres = chart_df["genre"].unique()
all_combinations = pd.MultiIndex.from_product(
    [unique_years, unique_genres], names=["year", "genre"]
)
all_combinations_df = pd.DataFrame(index=all_combinations).reset_index()

final_chart_df = pd.merge(
    all_combinations_df, chart_df, on=["year", "genre"], how="left"
).fillna(0)

final_chart_df.loc[final_chart_df["song_hotttnesss"] == 0, "count"] = 0
final_chart_df
# Out:
#      year       genre  song_hotttnesss    duration  count
# 0    1938       Blues         0.000000  171.676280    0.0
# 1    1938     Country         0.000000    0.000000    0.0
# 2    1938        Jazz         0.000000    0.000000    0.0
# 3    1938        Rock         0.000000    0.000000    0.0
# 4    1938         RnB         0.000000    0.000000    0.0
# ..    ...         ...              ...         ...    ...
# 850  2010        Punk         0.000000    0.000000    0.0
# 851  2010     New Age         0.000000    0.000000    0.0
# 852  2010  Electronic         0.575618  285.661587    8.0
# 853  2010         Rap         0.576644  179.495603    3.0
# 854  2010       World         0.000000  569.129340    0.0
#
# [855 rows x 5 columns]

# %% [markdown]
# We now work the user song interaction dataset. For the UI we need to show the top 5 songs played by the user. Also user_id is a alphanumeric string. For better UX we give fake names to each unique user_id. Following code snippets are used to achieve this.

# %%
# !unzip "train_triplets.txt.zip"
# Out:
# Archive:  train_triplets.txt.zip
# replace train_triplets.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:
# ^C

# %%
column_names = ["user_id", "song_id", "listen_count"]
user_play_counts_df = pd.read_csv(
    "train_triplets.txt", sep="\t", names=column_names, nrows=10_000
)

# %%
pc_df = msd_df[["song_id", "title"]]
group_df = user_play_counts_df.merge(pc_df, on="song_id")
top_5_songs = (
    group_df.groupby("user_id")
    .apply(lambda x: x.nlargest(5, "listen_count"))
    .reset_index(drop=True)
)

# %%
top_5_songs
# Out:
#                                      user_id             song_id  \
# 0   01655ae6bc52e29c9cd100a7dde4e9eeae5e4031  SOPRIUU12A8C133EF5
# 1   01655ae6bc52e29c9cd100a7dde4e9eeae5e4031  SODJMNX12A8C1320C4
# 2   0ef42a19efb74d0a05c308d00636c8d8d41bec0c  SOSCMSY12A8C13C1E9
# 3   12a4a991c8b53cd6906995caed8b1f2bd3b6436a  SOAQZZG12A8C135BFF
# 4   12a4a991c8b53cd6906995caed8b1f2bd3b6436a  SOIUVMN12A8AE47414
# 5   12a4a991c8b53cd6906995caed8b1f2bd3b6436a  SOSCNMY12AC3DFB313
# 6   17aa9f6dbdf753831da8f38c71b66b64373de613  SONMWXV12AB01803B4
# 7   18dc95f354220b343e98ebbb7c8564291284ed9f  SORWULZ12A6D4F5B1E
# 8   18dc95f354220b343e98ebbb7c8564291284ed9f  SOJUERX12AB0184DE1
# 9   3187e658fd71be99d68d96f3a61a436c8a607365  SOWWQXA12A81C1F9CA
# 10  403b3b867fc71dfdcc12652f30e88bdc7ccd9aa4  SOUELOC12AB0182DD1
# 11  4691b4c353503da2c108e372ff056a9ac847c4d1  SOPKTEV12A8C141E33
# 12  537340ff896dea11328910013cfe759413e1eeb3  SOYDERO12A6D4F72BC
# 13  5a905f000fc1ff3df7ca807d57edb608863db05d  SOMMONH12A6D4F41CD
# 14  5a905f000fc1ff3df7ca807d57edb608863db05d  SOWKLEE12A81C232AC
# 15  5a905f000fc1ff3df7ca807d57edb608863db05d  SOEDGBE12A670211D3
# 16  5a905f000fc1ff3df7ca807d57edb608863db05d  SOAKDHD12A6310F1AE
# 17  5a905f000fc1ff3df7ca807d57edb608863db05d  SOCXGVX12A67AD85A1
# 18  732f88be38fae217f8ab7e24c20dd072436e3e40  SORZKKV12A58A7B9E0
# 19  78e0065cacc15d6329be91b77045f12ab18cbea5  SOYDERO12A6D4F72BC
# 20  8814f5d1f1d7177aa2efb6de6454504f3bb7b7bc  SOXQBTU12A8C13F5E0
# 21  8dcb524ff75e0ad0f0a80aaccadf7bbaa3b89a41  SOCXGVX12A67AD85A1
# 22  8dcb524ff75e0ad0f0a80aaccadf7bbaa3b89a41  SOSXRBR12AB017C294
# 23  95942345306393998eb3a051ae5fa3c4d5afbaa4  SORYNOQ12A8AE46D2D
# 24  a1380d458c15706b9d5282304db81a5a78352e96  SORWULZ12A6D4F5B1E
# 25  a520488fcf049bbb5cd847cfa4f884c740692780  SOXQBTU12A8C13F5E0
# 26  a520488fcf049bbb5cd847cfa4f884c740692780  SORPBKY12AF72A5D5C
# 27  a58de017cbeda1763ea002fe027ed41b4ed53109  SOQZOIE12AB01859CF
# 28  a58de017cbeda1763ea002fe027ed41b4ed53109  SONMWXV12AB01803B4
# 29  b4e32cdb654ab914a0ac73d2bbc5cae142da405a  SOFVBVA12A8AE484E7
# 30  b61afb42335287239bd40e1dea50d849cbf8a9a9  SOYFUGN12A6D4FE4E0
# 31  b61afb42335287239bd40e1dea50d849cbf8a9a9  SORZKKV12A58A7B9E0
# 32  b6b799f34a204bd928ea014c243ddad6d0be4f8f  SORYNAN12A8C13CA99
# 33  bab8d135cf88852063ed4a084dd24c783d7ff841  SOWKLEE12A81C232AC
# 34  baf47ed8da24d607e50d8684cde78b923538640f  SOHILNH12A6701E1C3
# 35  baf47ed8da24d607e50d8684cde78b923538640f  SOHNFBA12AB018CD1D
# 36  baf47ed8da24d607e50d8684cde78b923538640f  SORZHCA12AB01846E3
# 37  baf47ed8da24d607e50d8684cde78b923538640f  SOURJIK12A8C138182
# 38  bd64f193f0f53f09d44ff48fd52830ff2fded392  SOUVDUA12A8C136305
# 39  d66f2f66f2bdc9aa3d0362a35fc91ccc844101f7  SOKNBWG12A58A7D0C8
# 40  d66f2f66f2bdc9aa3d0362a35fc91ccc844101f7  SOSNBUS12A8C13FCD0
# 41  e21477efb83bd323205ce6f5bd662f3df9d477e5  SOEBTRK12A8C141344
# 42  e21477efb83bd323205ce6f5bd662f3df9d477e5  SOZWOAM12AF72A0088
# 43  e4c05157f8cebdf3b9d689c441ba97c5ed5db05b  SOQXNTR12A8C143FF6
# 44  ea07020bb223c733ccc55aa925ebcc25c4d97377  SOCKJWI12AB018006A
# 45  fe979a7b199de3ee8a78486c10e5ed13587fc359  SOTHYJS12AF72A6210
#
#     listen_count                                        title
# 0              2                                   Home Again
# 1              1                                    Astronaut
# 2              1                                      Warrior
# 3              2                                Ain't No Good
# 4              1                                         City
# 5              1                                     Official
# 6              1                                    Year 3000
# 7              1              Queen Of My Double Wide Trailer
# 8              1                             Street Of Dreams
# 9              1                                       Scream
# 10             2                  Stickshifts And Safetybelts
# 11             3                                   Burnin' Up
# 12             1                                      Survive
# 13             5                                  The Maestro
# 14             3                                        Rage!
# 15             2                  Technologic (Vitalic Remix)
# 16             1           Face To Face (Cosmo VItelli Remix)
# 17             1                                        a joy
# 18             1                                   First Gear
# 19             1                                      Survive
# 20            11                                    Knowledge
# 21             1                                        a joy
# 22             1                                            M
# 23             6                                     Rainbows
# 24             5              Queen Of My Double Wide Trailer
# 25             1                                    Knowledge
# 26             1                                  Sweet Woman
# 27             8                 Just One Second (Apex Remix)
# 28             1                                    Year 3000
# 29             1                              Leave Right Now
# 30             3                                   Undeclared
# 31             1                                   First Gear
# 32             2                                  Mi Princesa
# 33             1                                        Rage!
# 34             1  Once In A Lifetime (Remastered LP Version )
# 35             1                                   Black Gold
# 36             1                           Insomniac Olympics
# 37             1                            Not Falling Apart
# 38             1                                      Wake Up
# 39             1                                Prelude 12/21
# 40             1                                   Blue Bossa
# 41             2                                        Gecko
# 42             1                                   Give It Up
# 43             9                            Pocket Revolution
# 44            21                                      Amazing
# 45             1                                  Autosleeper

# %%
from faker import Faker

fake = Faker()

def generate_fake_names(df):
    user_ids = df["user_id"].unique()
    fake_names = [fake.name() for _ in range(len(user_ids))]
    fake_mapping = dict(zip(user_ids, fake_names))
    df["fake_name"] = df["user_id"].map(fake_mapping)
    return df

df_with_fake_names = generate_fake_names(top_5_songs)
df_with_fake_names
# Out:
#                                      user_id             song_id  \
# 0   01655ae6bc52e29c9cd100a7dde4e9eeae5e4031  SOPRIUU12A8C133EF5
# 1   01655ae6bc52e29c9cd100a7dde4e9eeae5e4031  SODJMNX12A8C1320C4
# 2   0ef42a19efb74d0a05c308d00636c8d8d41bec0c  SOSCMSY12A8C13C1E9
# 3   12a4a991c8b53cd6906995caed8b1f2bd3b6436a  SOAQZZG12A8C135BFF
# 4   12a4a991c8b53cd6906995caed8b1f2bd3b6436a  SOIUVMN12A8AE47414
# 5   12a4a991c8b53cd6906995caed8b1f2bd3b6436a  SOSCNMY12AC3DFB313
# 6   17aa9f6dbdf753831da8f38c71b66b64373de613  SONMWXV12AB01803B4
# 7   18dc95f354220b343e98ebbb7c8564291284ed9f  SORWULZ12A6D4F5B1E
# 8   18dc95f354220b343e98ebbb7c8564291284ed9f  SOJUERX12AB0184DE1
# 9   3187e658fd71be99d68d96f3a61a436c8a607365  SOWWQXA12A81C1F9CA
# 10  403b3b867fc71dfdcc12652f30e88bdc7ccd9aa4  SOUELOC12AB0182DD1
# 11  4691b4c353503da2c108e372ff056a9ac847c4d1  SOPKTEV12A8C141E33
# 12  537340ff896dea11328910013cfe759413e1eeb3  SOYDERO12A6D4F72BC
# 13  5a905f000fc1ff3df7ca807d57edb608863db05d  SOMMONH12A6D4F41CD
# 14  5a905f000fc1ff3df7ca807d57edb608863db05d  SOWKLEE12A81C232AC
# 15  5a905f000fc1ff3df7ca807d57edb608863db05d  SOEDGBE12A670211D3
# 16  5a905f000fc1ff3df7ca807d57edb608863db05d  SOAKDHD12A6310F1AE
# 17  5a905f000fc1ff3df7ca807d57edb608863db05d  SOCXGVX12A67AD85A1
# 18  732f88be38fae217f8ab7e24c20dd072436e3e40  SORZKKV12A58A7B9E0
# 19  78e0065cacc15d6329be91b77045f12ab18cbea5  SOYDERO12A6D4F72BC
# 20  8814f5d1f1d7177aa2efb6de6454504f3bb7b7bc  SOXQBTU12A8C13F5E0
# 21  8dcb524ff75e0ad0f0a80aaccadf7bbaa3b89a41  SOCXGVX12A67AD85A1
# 22  8dcb524ff75e0ad0f0a80aaccadf7bbaa3b89a41  SOSXRBR12AB017C294
# 23  95942345306393998eb3a051ae5fa3c4d5afbaa4  SORYNOQ12A8AE46D2D
# 24  a1380d458c15706b9d5282304db81a5a78352e96  SORWULZ12A6D4F5B1E
# 25  a520488fcf049bbb5cd847cfa4f884c740692780  SOXQBTU12A8C13F5E0
# 26  a520488fcf049bbb5cd847cfa4f884c740692780  SORPBKY12AF72A5D5C
# 27  a58de017cbeda1763ea002fe027ed41b4ed53109  SOQZOIE12AB01859CF
# 28  a58de017cbeda1763ea002fe027ed41b4ed53109  SONMWXV12AB01803B4
# 29  b4e32cdb654ab914a0ac73d2bbc5cae142da405a  SOFVBVA12A8AE484E7
# 30  b61afb42335287239bd40e1dea50d849cbf8a9a9  SOYFUGN12A6D4FE4E0
# 31  b61afb42335287239bd40e1dea50d849cbf8a9a9  SORZKKV12A58A7B9E0
# 32  b6b799f34a204bd928ea014c243ddad6d0be4f8f  SORYNAN12A8C13CA99
# 33  bab8d135cf88852063ed4a084dd24c783d7ff841  SOWKLEE12A81C232AC
# 34  baf47ed8da24d607e50d8684cde78b923538640f  SOHILNH12A6701E1C3
# 35  baf47ed8da24d607e50d8684cde78b923538640f  SOHNFBA12AB018CD1D
# 36  baf47ed8da24d607e50d8684cde78b923538640f  SORZHCA12AB01846E3
# 37  baf47ed8da24d607e50d8684cde78b923538640f  SOURJIK12A8C138182
# 38  bd64f193f0f53f09d44ff48fd52830ff2fded392  SOUVDUA12A8C136305
# 39  d66f2f66f2bdc9aa3d0362a35fc91ccc844101f7  SOKNBWG12A58A7D0C8
# 40  d66f2f66f2bdc9aa3d0362a35fc91ccc844101f7  SOSNBUS12A8C13FCD0
# 41  e21477efb83bd323205ce6f5bd662f3df9d477e5  SOEBTRK12A8C141344
# 42  e21477efb83bd323205ce6f5bd662f3df9d477e5  SOZWOAM12AF72A0088
# 43  e4c05157f8cebdf3b9d689c441ba97c5ed5db05b  SOQXNTR12A8C143FF6
# 44  ea07020bb223c733ccc55aa925ebcc25c4d97377  SOCKJWI12AB018006A
# 45  fe979a7b199de3ee8a78486c10e5ed13587fc359  SOTHYJS12AF72A6210
#
#     listen_count                                        title  \
# 0              2                                   Home Again
# 1              1                                    Astronaut
# 2              1                                      Warrior
# 3              2                                Ain't No Good
# 4              1                                         City
# 5              1                                     Official
# 6              1                                    Year 3000
# 7              1              Queen Of My Double Wide Trailer
# 8              1                             Street Of Dreams
# 9              1                                       Scream
# 10             2                  Stickshifts And Safetybelts
# 11             3                                   Burnin' Up
# 12             1                                      Survive
# 13             5                                  The Maestro
# 14             3                                        Rage!
# 15             2                  Technologic (Vitalic Remix)
# 16             1           Face To Face (Cosmo VItelli Remix)
# 17             1                                        a joy
# 18             1                                   First Gear
# 19             1                                      Survive
# 20            11                                    Knowledge
# 21             1                                        a joy
# 22             1                                            M
# 23             6                                     Rainbows
# 24             5              Queen Of My Double Wide Trailer
# 25             1                                    Knowledge
# 26             1                                  Sweet Woman
# 27             8                 Just One Second (Apex Remix)
# 28             1                                    Year 3000
# 29             1                              Leave Right Now
# 30             3                                   Undeclared
# 31             1                                   First Gear
# 32             2                                  Mi Princesa
# 33             1                                        Rage!
# 34             1  Once In A Lifetime (Remastered LP Version )
# 35             1                                   Black Gold
# 36             1                           Insomniac Olympics
# 37             1                            Not Falling Apart
# 38             1                                      Wake Up
# 39             1                                Prelude 12/21
# 40             1                                   Blue Bossa
# 41             2                                        Gecko
# 42             1                                   Give It Up
# 43             9                            Pocket Revolution
# 44            21                                      Amazing
# 45             1                                  Autosleeper
#
#             fake_name
# 0       Barry Jenkins
# 1       Barry Jenkins
# 2        Donna Murphy
# 3           Joe Davis
# 4           Joe Davis
# 5           Joe Davis
# 6        Daryl Wright
# 7       Jeffrey James
# 8       Jeffrey James
# 9    Jessica Anderson
# 10       Jeffrey Paul
# 11     Cynthia Foster
# 12        Duane Reyes
# 13         Paul Payne
# 14         Paul Payne
# 15         Paul Payne
# 16         Paul Payne
# 17         Paul Payne
# 18    Crystal Hickman
# 19     Jessica Miller
# 20      David Hoffman
# 21     Charles Cannon
# 22     Charles Cannon
# 23    Jonathan Murphy
# 24  Stefanie Hamilton
# 25        Bryan Brown
# 26        Bryan Brown
# 27    Marissa Kennedy
# 28    Marissa Kennedy
# 29     Brandon Romero
# 30    Daniel Sandoval
# 31    Daniel Sandoval
# 32     Deanna Gilmore
# 33  Mitchell Thompson
# 34   Brandon Reynolds
# 35   Brandon Reynolds
# 36   Brandon Reynolds
# 37   Brandon Reynolds
# 38          Holly Lee
# 39       Robert Brown
# 40       Robert Brown
# 41         April Kerr
# 42         April Kerr
# 43     Jonathan Smith
# 44      Michael Cross
# 45       John Osborne
